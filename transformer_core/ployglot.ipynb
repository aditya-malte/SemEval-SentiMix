# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

import os

try:
  os.chdir('drive/My Drive/Colab Notebooks/bull_bear')
  print('Changed directory')
  print(os.getcwd())
except:
  print('Cannot change directory')
  print(os.getcwd())

# %%
# !pip install pyconll
# !pip install polyglot pyicu pycld2 morfessor
# !sudo apt-get install python-numpy libicu-dev
# %%bash
polyglot download embeddings2.en transliteration2.hi transliteration2.gl

# %%
# from polyglot.text import Text
# blob = """Sach batao what is the time"""
# text = Text(blob)
# for x in text.transliterate("hi"):
#   print(x)
